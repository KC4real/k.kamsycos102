# %%
import tkinter as tk
from tkinter import messagebox   


    
def welcome(firstname):
    window = tk.Toplevel(root)
    window.title("EMPLOYEE")
    window.geometry("500x150")
    label1 = tk.Label(window, text = f"welcome {firstname}\n")
    label1.pack()
    label2 = tk.Label(window, text = f"welcome {firstname} we're pleased to have you,thanks for logging in")
    label2.pack()
    root.mainloop()

def submit():

    ln = ["ADENIRAN","ADEWUMI","ADOH-AJAGBE","AGBAKURU-NWOGU","AGBAKWURU","AKINDE","ARNIKA","","ATELLY","AZOGU","BETURE","CHUKWUMA","EBI",
          "EGBORO","EJEDIMU","ELERI","EZE","EZEONYE","GIWA","ICHA","IKPATI","ILOENYOSI","IYAWE","NWOKOLO","NWOTOKUBO","OBASOGIE","OBI ","OBIALOR",
          "OGBONNA","OIGBOCHIE","OKOCHA-OJEAH","OKOLO","OKORO","OLOWOKERE","OLUBUADE","OSEMEKE","OSSAI","PETER","QUADRI","UDE-IBE","UMEH"]

    fn = ["Oluwatamilore","Ayomide","Oshim","Chukwunonye","Chiemeziem","Oluwatimehin","Osose","Daniel","Onyekachi","Shalom","Nedi","Stephanie","Jason",
          "Edward","Otu","Onyinyechi","Makuochukwu","Moyosore","Ayonete","Eche","Michael","Oluwadamilola","Chijindu","Joseph","Daisy","Samuel","Betha",
          "Boluwatife","Mary","Raphael","Victor","Derek","Akorede","Rasheed","Daniel","Mary-Cynthia","Owoede","Oluwafikunmi","Uchenna","Ejike"]

    dep = ["LOGISTICS","ACCOUNTING","DELIVERY","ADMINISTRATION"]

    logistics = ["ADENIRAN Oluwatamilore","AGBAKWURU Chiemeziem","ARNIKA Osose","CHUKWUMA Nedi","EZEONYE Makuochukwu","GIWA	Moyosore","NWOKOLO Chijindu",
                 "NWOTOKUBO Joseph","OKORO Derek","OSSAI Mary-Cynthia","PETER Owoede"]

    accounting =["ADEWUMI Ayomide","AGBAKURU-NWOGU Chukwunonye","AKINDE Oluwatimehin","EBI Stephanie","ICHA Ayonete","IKPATI Eche","OBASOGIE Daisy",
                 "OBI Samuel","OBIALOR Betha","OLOWOKERE Akorede","OLUBUADE	Rasheed","OSEMEKE Daniel"]

    delivery = ["ADOH-AJAGBE Oshim","ATELLY	Daniel","AZOGU Onyekachi","BETURE Shalom","EJEDIMU Edward","ILOENYOSI ichael","IYAWE Oluwadamilola",
                "OGBONNA Boluwatife","OIGBOCHIE	Mary","QUADRI Oluwafikunmi","UDE-IBE Uchenna"]

    administration = ["EGBORO Jason","ELERI	Otu","EZE Onyinyechi","OKOCHA-OJEAH	Raphael","OKOLO	Victor","UMEH Ejike"]


    firstname = firstname_entry.get()
    lastname = lastname_entry.get()
    department = department_entry.get()
    if firstname in fn and lastname in ln and department in dep and department == "LOGISTICS":
        window2 = tk.Toplevel(root)
        listbox = tk.Listbox(window2,height = 20,width =150)
        window2.geometry("300x250")
        label = tk.Label(window2, text = "LOGISTICS")
        for i in logistics:
            listbox.insert(1,i)
        label.pack()
        listbox.pack()
        welcome(firstname)

    elif firstname in fn and lastname in ln and department in dep and department == "ACCOUNTING":
        window2 = tk.Toplevel(root)
        listbox = tk.Listbox(window2,height = 20,width =150)
        window2.geometry("300x250")
        label = tk.Label(window2, text = "ACCOUNTING")
        for i in accounting:
            listbox.insert(1,i)
        label.pack()
        listbox.pack()
        welcome(firstname)

    elif firstname in fn and lastname in ln and department in dep and department == "DELIVERY":
        window2 = tk.Toplevel(root)
        listbox = tk.Listbox(window2,height = 20,width =150)
        window2.geometry("300x250")
        label = tk.Label(window2, text = "DELIVERY")
        for i in delivery:
            listbox.insert(1,i)
        label.pack()
        listbox.pack()
        welcome(firstname)

    elif firstname in fn and lastname in ln and department in dep and department == "ADMINISTRATION":
        window2 = tk.Toplevel(root)
        listbox = tk.Listbox(window2,height = 20,width =150)
        window2.geometry("300x250")
        label = tk.Label(window2, text = "ADMINISTRATION")
        for i in administration:
            listbox.insert(1,i)
        label.pack()
        listbox.pack()
        welcome(firstname)
    else:
        messagebox.showerror("login error","THIS CUSTOMER DOES NOT EXIST,PLEASE CHECK YOUR LOGIN DETAILS AND TRY AGAIN")
                


root = tk.Tk()
root.title("login form")
root.geometry("500x200")

department_label = tk.Label(root, text = "department (all caps please): ")
department_label.pack()
department_entry = tk.Entry(root)
department_entry.pack()

firstname_label = tk.Label(root, text = "firstname (first letter in caps): ")
firstname_label.pack()
firstname_entry = tk.Entry(root)
firstname_entry.pack()

lastname_label = tk.Label(root, text = "lastname (all caps please): ")
lastname_label.pack()
lastname_entry = tk.Entry(root)
lastname_entry.pack()

submit_button = tk.Button(root, text="submit", command = submit)
submit_button.pack()

root.mainloop()
